# %% [markdown]
# # Pandas 시각화
# 판다시 자체적으로 matplotlib 를 기반으로 한 시각화기능을 지원한다.
# Series나 DataFrame에 plot() 함수나 plot accessor를 사용한다.
# matplotlib을 이용해 그래프에 대한 설정을 추가로 할 수 있다.
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %% [markdown]
# ## plot()
# - kind 매개변수에 지정한 값에 따라 다양한 그래프를 그릴 수 있다.
# - **kind** : 그래프 종류 지정
#     - **'line'**: line plot (default)
#     - **'bar'**: vertical bar plot
#     - **'barh'**: horizontal bar plot
#     - **'hist'**: histogram
#     - **'box'**: boxplot
#     - **'kde'**: Kernel Density Estimation plot
#     - **'pie'**: pie plot
#     - **'scatter'**: scatter plot

# %% [markdown]
# ## 막대 그래프
# - index가 무슨 값인지를 가리키는 축으로 사용된다. ==> 라벨로 사용

# %%
import pandas as pd
import matplotlib.pyplot as plt

tips = pd.read_csv("data/tips.csv")

# %%
tips['sex'].value_counts().plot(kind="bar",title="Title",xlabel="성별")
# Out:
# <Axes: title={'center': 'Title'}, xlabel='성별'>

# %%
df = tips.pivot_table(index="sex",columns="smoker",values="tip",aggfunc="count")

# %%
tips.pivot_table(index="sex",columns="smoker",values="tip",aggfunc="count").plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='sex'>

# %% [markdown]
# ## 파이차트

# %%
v = tips["day"].value_counts()
v
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
v.plot(kind="pie",autopct="%.2f%%",explode=[0.2,0,0,0],shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 히스토그램, KDE(밀도그래프)

# %%
tips["total_bill"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
tips[["total_bill","tip"]].plot(kind="hist",alpha=0.6,bins=30)
plt.show()

# %%
tips[["total_bill","tip"]].plot(kind="kde")
plt.show()

# %% [markdown]
# ## Boxplot (상자그래프)

# %%
tips["total_bill"].plot(kind="box",whis=3)
plt.show()

# %%
tips[["total_bill","tip"]].plot(kind="box")
plt.show()

# %% [markdown]
# ## scatter plot (산점도)

# %%
tips.plot(kind="scatter",x="total_bill",y="tip")
plt.show()

# %%
tips.select_dtypes(exclude="object").corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# ## Line Plot

# %%
df = pd.read_excel("data/강수량.xlsx",index_col="계절")
display(df)
display(df.T) # 컬럼 인덱스 위치 변경
df = df.T
# Out:
#      2009   2010    2011   2012   2013   2014   2015   2016   2017
# 계절
# 봄   231.3  302.9   256.9  256.5  264.3  215.9  223.2  312.8  118.6
# 여름  752.0  692.6  1053.6  770.6  567.5  599.8  387.1  446.2  609.7
# 가을  143.1  307.6   225.5  363.5  231.2  293.1  247.7  381.6  172.5
# 겨울  142.3   98.7    45.6  139.3   59.9   76.9  109.1  108.1   75.6
# 계절        봄      여름     가을     겨울
# 2009  231.3   752.0  143.1  142.3
# 2010  302.9   692.6  307.6   98.7
# 2011  256.9  1053.6  225.5   45.6
# 2012  256.5   770.6  363.5  139.3
# 2013  264.3   567.5  231.2   59.9
# 2014  215.9   599.8  293.1   76.9
# 2015  223.2   387.1  247.7  109.1
# 2016  312.8   446.2  381.6  108.1
# 2017  118.6   609.7  172.5   75.6

# %%
df.plot(figsize=(15,4)) #기본은 Lineplot, X = 인덱스, Y= 컬럼값이 기본 값
plt.show()
